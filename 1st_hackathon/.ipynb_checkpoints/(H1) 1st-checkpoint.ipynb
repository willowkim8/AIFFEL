# %% [markdown]
# # 모듈 부르기

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import warnings
warnings.filterwarnings("ignore")

import os
from os.path import join

import pandas as pd
import numpy as np

import missingno as msno

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import KFold, cross_val_score
import xgboost as xgb
import lightgbm as lgb

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_dir = os.getenv('HOME')+'/aiffel/Exploration/1st_hackathon' 

train_data_path = join(data_dir, 'sales_train.csv') 
# sub_data_path = join(data_dir, 'test.csv')

# %%
data = pd.read_csv(train_data_path)
print('train data dim : {}'.format(data.shape))
# Out:
# train data dim : (2935849, 6)

# %% [markdown]
#  data 개수는 300만개가 살짝 안되고, 6가지 컬럼이 있다.

# %%
print(data.columns)
# Out:
# Index(['date', 'date_block_num', 'shop_id', 'item_id', 'item_price',
#        'item_cnt_day'],
#       dtype='object')

# %%
anomal_count = data['item_id'].map(lambda x : x < 0.0)
anomal_count = data[anomal_count]
print(anomal_count)
# Out:
# Empty DataFrame
# Columns: [date, date_block_num, shop_id, item_id, item_price, item_cnt_day]
# Index: []

# %%
print(anomal_count.groupby('item_cnt_day').count().sort_values(['item_cnt_day'],ascending=False))
anomal_item = anomal_count.groupby('item_id').count().sort_values(['date'], ascending=False)
print(anomal_item)
# Out:
# Empty DataFrame
# Columns: [date, date_block_num, shop_id, item_id, item_price]
# Index: []
# Empty DataFrame
# Columns: [date, date_block_num, shop_id, item_price, item_cnt_day]
# Index: []

# %%
data.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
print(data['date_block_num'].max())
# Out:
# 33

# %%
items = pd.read_csv('items.csv')
items.head(50)
# Out:
#                                             item_name  item_id  \
# 0           ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1   !ABBYY FineReader 12 Professional Edition Full...        1
# 2       ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3     ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4         ***КОРОБКА (СТЕКЛО)                       D        4
# 5   ***НОВЫЕ АМЕРИКАНСКИЕ ГРАФФИТИ  (UNI)         ...        5
# 6            ***УДАР ПО ВОРОТАМ (UNI)               D        6
# 7          ***УДАР ПО ВОРОТАМ-2 (UNI)               D        7
# 8            ***ЧАЙ С МУССОЛИНИ                     D        8
# 9       ***ШУГАРЛЭНДСКИЙ ЭКСПРЕСС (UNI)             D        9
# 10          *ЗА ГРАНЬЮ СМЕРТИ                       D       10
# 11          *ЛИНИЯ СМЕРТИ                           D       11
# 12                    *МИХЕЙ И ДЖУМАНДЖИ  Сука любовь       12
# 13          *СПАСАЯ ЭМИЛИ                           D       13
# ...

# %%
item_uniq = np.unique(items)
print(len(item_uniq))
item_uniq
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-251da8898256> in <module>
# ----> 1 item_uniq = np.unique(items)
#       2 print(len(item_uniq))
#       3 item_uniq
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     261     ar = np.asanyarray(ar)
#     262     if axis is None:
# --> 263         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     264         return _unpack_tuple(ret)
#     265
#
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/numpy/lib/arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     309         aux = ar[perm]
#     310     else:
# --> 311         ar.sort()
#     312         aux = ar
# ...

# %%
print(data['item_cnt_day'].describe())
# Out:
# count    2.935849e+06
# mean     1.242641e+00
# std      2.618834e+00
# min     -2.200000e+01
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      2.169000e+03
# Name: item_cnt_day, dtype: float64

# %% [markdown]
# # 모양바꾸기

# %%
data_ndarray = data.values
data_ndarray
# Out:
# array([['02.01.2013', 0, 59, 22154, 999.0, 1.0],
#        ['03.01.2013', 0, 25, 2552, 899.0, 1.0],
#        ['05.01.2013', 0, 25, 2552, 899.0, -1.0],
#        ...,
#        ['14.10.2015', 33, 25, 7459, 349.0, 1.0],
#        ['22.10.2015', 33, 25, 7440, 299.0, 1.0],
#        ['03.10.2015', 33, 25, 7460, 299.0, 1.0]], dtype=object)

# %%
org_data = data
del data['date']
del data['date_block_num']
del data['shop_id']
del data['item_cnt_day']

id_and_price = data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-066189915b11> in <module>
# ...

# %%
data.head()
# Out:
#    item_id  item_price
# 0    22154      999.00
# 1     2552      899.00
# 2     2552      899.00
# 3     2554     1709.05
# 4     2555     1099.00

# %%
data_ndarray = data.values
data_ndarray
# Out:
# array([[22154.,   999.],
#        [ 2552.,   899.],
#        [ 2552.,   899.],
#        ...,
#        [ 7459.,   349.],
#        [ 7440.,   299.],
#        [ 7460.,   299.]])

# %%
# 행렬
data_ndarray.shape
# Out:
# (2935849, 2)

# %%
data_ndarray[0]
# Out:
# array([22154.,   999.])

# %%
# item_id만 다시 array로
data_item_id = data_ndarray[:, 0]
data_item_id
# Out:
# array([22154.,  2552.,  2552., ...,  7459.,  7440.,  7460.])

# %%
item_id_uniq = np.unique(data_item_id)
print(len(item_id_uniq))
item_id_uniq
# Out:
# 21807
# array([0.0000e+00, 1.0000e+00, 2.0000e+00, ..., 2.2167e+04, 2.2168e+04,
#        2.2169e+04])

# %%
print(anomal_count.groupby('item_cnt_day').count().sort_values(['item_cnt_day'],ascending=False))
anomal_item = anomal_count.groupby('item_id').count().sort_values(['date'], ascending=False)
print(anomal_item)

# %%
from collections import OrderedDict
unique_item_id = OrderedDict.fromkeys(data_ndarray[:, 0])
print(len(unique_item_id))
unique_item_id
# Out:
# 21807
# OrderedDict([(22154.0, None),
#              (2552.0, None),
#              (2554.0, None),
#              (2555.0, None),
#              (2564.0, None),
#              (2565.0, None),
#              (2572.0, None),
#              (2573.0, None),
#              (2574.0, None),
#              (2593.0, None),
#              (2604.0, None),
#              (2607.0, None),
#              (2609.0, None),
#              (2548.0, None),
#              (2611.0, None),
#              (2546.0, None),
#              (2515.0, None),
#              (2705.0, None),
#              (2715.0, None),
#              (2716.0, None),
#              (2719.0, None),
#              (2720.0, None),
#              (2473.0, None),
#              (2480.0, None),
#              (2731.0, None),
#              (2746.0, None),
#              (2748.0, None),
#              (2522.0, None),
#              (2614.0, None),
#              (2798.0, None),
#              (2833.0, None),
# ...

# %%
print(data['date_block_num'].max())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/aiffel/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date_block_num'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-851fa34212f9> in <module>
# ...

# %%
from collections import OrderedDict
unique_item_id = OrderedDict.fromkeys(data_ndarray[:, 0])
print(len(unique_item_id))
unique_item_id

# %%
# 생각해보니 
# from collections import OrderedDict
# unique_item_price = OrderedDict.fromkeys(data_ndarray[:, 1])
# print(len(unique_item_price))
# unique_item_price
# Out:
# 19993
# OrderedDict([(999.0, None),
#              (899.0, None),
#              (1709.05, None),
#              (1099.0, None),
#              (349.0, None),
#              (549.0, None),
#              (239.0, None),
#              (299.0, None),
#              (399.0, None),
#              (279.0, None),
#              (1699.0, None),
#              (1708.95, None),
#              (1649.0, None),
#              (1799.0, None),
#              (898.5, None),
#              (149.0, None),
#              (2699.0, None),
#              (58.0, None),
#              (599.0, None),
#              (1399.0, None),
#              (799.0, None),
#              (1999.0, None),
#              (449.0, None),
#              (99.0, None),
#              (1998.5, None),
#              (448.5, None),
#              (949.0, None),
#              (1299.0, None),
#              (199.0, None),
#              (1499.0, None),
#              (499.5, None),
#              (2199.0, None),
# ...

# %%
from collections import OrderedDict
unique = OrderedDict.fromkeys(data_ndarray[0])
unique_ndarray
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-0e0f80e802c8> in <module>
#       1 from collections import OrderedDict
#       2 unique = OrderedDict.fromkeys(data_ndarray[0])
# ----> 3 unique_ndarray
#
# NameError: name 'unique_ndarray' is not defined

# %%
data_dict=data.to_dict()
data_dict
# Out:
# {'item_id': {0: 22154,
#   1: 2552,
#   2: 2552,
#   3: 2554,
#   4: 2555,
#   5: 2564,
#   6: 2565,
#   7: 2572,
#   8: 2572,
#   9: 2573,
#   10: 2574,
#   11: 2574,
#   12: 2574,
#   13: 2574,
#   14: 2574,
#   15: 2574,
#   16: 2574,
#   17: 2574,
#   18: 2574,
#   19: 2574,
#   20: 2593,
#   21: 2604,
#   22: 2604,
#   23: 2607,
#   24: 2607,
#   25: 2609,
#   26: 2548,
#   27: 2611,
#   28: 2546,
#   29: 2515,
#   30: 2705,
#   31: 2705,
#   32: 2705,
#   33: 2715,
#   34: 2715,
#   35: 2716,
#   36: 2716,
#   37: 2719,
#   38: 2719,
#   39: 2719,
#   40: 2720,
#   41: 2473,
#   42: 2480,
#   43: 2731,
#   44: 2731,
#   45: 2746,
#   46: 2746,
#   47: 2746,
#   48: 2746,
#   49: 2746,
#   50: 2746,
#   51: 2746,
#   52: 2748,
#   53: 2748,
#   54: 2748,
#   55: 2522,
#   56: 2614,
#   57: 2614,
#   58: 2798,
#   59: 2833,
#   60: 2833,
#   61: 2833,
#   62: 2833,
#   63: 2833,
#   64: 2833,
#   65: 2835,
#   66: 2835,
#   67: 2835,
#   68: 2836,
#   69: 2836,
#   70: 2844,
# ...

# %% [markdown]
# dict보다 ndarray 를 처리하는 방법을 찾아보자

# %% [markdown]
# # 간단한 전처리
# 각 변수들에 대해 결측 유무를 확인하고, 분포를 확인해보면서 간단하게 전처리를 하겠습니다.
# # 결측치 확인
# 먼저 데이터에 결측치가 있는지를 확인하겠습니다.
# missingno 라이브러리의 matrix 함수를 사용하면, 데이터의 결측 상태를 시각화를 통해 살펴볼 수 있습니다.

# %%
msno.matrix(data)

# %% [markdown]
# 모든 변수에 결측치가 없는 것으로 보이지만, 혹시 모르니 확실하게 살펴보겠습니다.

# %%
# 직접 결측치의 개수를 출력해서 확인
for c in data.columns:
    print('{} : {}'.format(c, len(data.loc[pd.isnull(data[c]), c].values)))

# %% [markdown]
# # 각 변수들의 분포 확인
# 한쪽으로 치우친 분포는 모델이 결과를 예측하기에 좋지 않은 영향을 미치므로 다듬어줄 필요가 있습니다.

# %%
# 가로스크롤 때문에 그래프 확인이 불편하다면 figsize의 x값을 조절해 보세요. 
fig, ax = plt.subplots(3, 2, figsize=(12, 12))  

# id 변수(count==0인 경우)는 제외하고 분포를 확인합니다.
count = 1
columns = data.columns
for row in range(6):
    for col in range(2):
        print(row, col, count)
        sns.kdeplot(data[columns[count]], ax=ax[row][col])
        ax[row][col].set_title(columns[count], fontsize=15)
        count += 1
        if count == 5 :
            break

# %% [markdown]
# # log로 치우침 줄이기 할라했는데 왜 안될까

# %%
skew_columns = ['item_price', 'item_cnt_day']

for c in skew_columns:
    data[c] = np.log1p(data[c].values)

# %%
fig, ax = plt.subplots(2, 1, figsize=(10, 15))

count = 0
for row in range(2):
    for col in range(2):
        if count == 5:
            break
        sns.kdeplot(data[skew_columns[count]], ax=ax[row][col])
        ax[row][col].set_title(skew_columns[count], fontsize=15)
        count+=1

# %% [markdown]
# # 변수 지정
# 위에서 저장해두었던 train_len을 인덱스로 활용해서 :train_len까지는 학습 데이터, 즉 x에 저장하고,
# train_len: 부터는 실제로 추론을 해야 하는 테스트 데이터, 즉 sub 변수에 저장합니다

# %%
sub = data.iloc[train_len:, :]
x = data.iloc[:train_len, :] 

print(x.shape)
print(sub.shape)
