# %% [markdown]
# # STEP 0. 작업환경 구성하기

# %% [markdown]
# ```
# ! pip install imageio
# ! pip install Pillow
# ! mkdir -p ~/aiffel/dcgan_newimage/cifar10/generated_samples
# ! mkdir -p ~/aiffel/dcgan_newimage/cifar10/training_checkpoints
# ! mkdir -p ~/aiffel/dcgan_newimage/cifar10/training_history
# ```

# %%
import os
import glob
import time

import PIL
import imageio
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from IPython import display
import matplotlib.pyplot as plt
# %matplotlib inline

print("tensorflow", tf.__version__)
# Out:
# tensorflow 2.2.0

# %% [markdown]
# 데이터셋이 이미 tf.keras에 들어가 있기 때문에 꺼내기만 하면 되고
# 그런데 분류문제가 아니기 때문에 라벨이 필요가 없다
# 언더바로 라벨 데이터를 무시하겠음

# %% [markdown]
# # STEP 1. 데이터셋 구성하기

# %%
cifar10 = tf.keras.datasets.cifar10

(train_x, _), (test_x, _) = cifar10.load_data()

train_x.shape
# Out:
# (50000, 32, 32, 3)

# %%
print("max pixel:", train_x.max())
print("min pixel:", train_x.min())
# Out:
# max pixel: 255
# min pixel: 0

# %%
train_x = (train_x - 127.5) / 127.5 # 이미지를 [-1, 1]로 정규화합니다.

print("max pixel:", train_x.max())
print("min pixel:", train_x.min())
# Out:
# max pixel: 1.0
# min pixel: -1.0

# %%
train_x.shape
# Out:
# (50000, 32, 32, 3)

# %%
test_x.shape
# Out:
# (10000, 32, 32, 3)

# %%
# 데이터 확인하기  
plt.figure(figsize=(10,10))
plt.imshow(train_x[1].reshape(32, 32, 3))
plt.colorbar()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.figure(figsize=(20, 10))

for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(train_x[i].reshape(32, 32, 3))
    plt.title(f'index: {i}')
    plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
# random으로 추출
plt.figure(figsize=(15, 15))

for i in range(25):
    # [[my CODE]]
    rand = np.random.randint(50000)
    plt.subplot(5, 5, i+1)
    plt.imshow(train_x[rand].reshape(32, 32, 3))
    plt.title(f'index: {rand}')
    plt.axis('off')

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %% [markdown]
# # STEP 2. 생성자 모델 구현하기

# %% [markdown]
# - (32, 32, 3)의 shape를 가진 이미지를 생성하는 생성자 모델 구현 함수를 작성해 봅시다.
# - noise = tf.random.normal(\[1, 100\])로 생성된 랜덤 노이즈를 입력으로 하여 방금 구현한 생성자로 랜덤 이미지를 생성해 봅시다.
# - 생성된 랜덤 이미지가 생성자 출력 규격에 잘 맞는지 확인해 봅시다.

# %%
BUFFER_SIZE = 50000
BATCH_SIZE = 256

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(train_x).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# ## (32, 32, 3)의 shape를 가진 이미지를 생성하는 생성자 모델 구현 함수를 작성

# %%
def make_generator_model():

    # Start
    model = tf.keras.Sequential()

    # First: Dense layer
    model.add(layers.Dense(8*8*768, use_bias=False, input_shape=(100,)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    # Second: Reshape layer
    model.add(layers.Reshape((8, 8, 768))) # 256*3=768

    # Third: Conv2DTranspose layer
    model.add(layers.Conv2DTranspose(128*3, kernel_size=(5, 5), strides=(1, 1), padding='same', use_bias=False))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    # Fourth: Conv2DTranspose layer
    model.add(layers.Conv2DTranspose(64*3, kernel_size=(5, 5), strides=(2, 2), padding='same', use_bias=False))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    # Fifth: Conv2DTranspose layer
    model.add(layers.Conv2DTranspose(3, kernel_size=(5, 5), strides=(2, 2), padding='same', use_bias=False, \
                                     activation='tanh'))

    return model

# %% [markdown]
# make_generator_model이라는 함수를 만들어서 생성자를 생성할 수 있도록
#
# **함수 내부**
# * tf.keras.Sequential()로 모델을 시작한 후 레이어를 차곡차곡 쌓아줌
# * Conv2DTranspose 층은 일반적인 Conv2D와 반대로 이미지 사이즈를 넓혀주는 층
# * 세 번의 Conv2DTranspose 층을 이용해 (8, 8, 768) → (16, 16, 192) → (32, 32, 3) 순으로 이미지를 키워나간다
# * 여기서 최종 사이즈인 (32, 32, 3)은 우리가 준비했던 데이터셋과 형상이 동일
# * BatchNormalization 레이어는 신경망의 가중치가 폭발하지 않도록 가중치 값을 정규화
# * 중간층들의 활성화 함수는 모두 LeakyReLU를 사용
# * 마지막 층에는 활성화 함수로 tanh를 사용하는데, 이는 우리가 -1 ~ 1 이내의 값으로 픽셀값을 정규화시켰던 데이터셋과 동일하게 하기 위함
#
# **생성자의 입력 벡터는 어떤 형태입니까?**
# >모델은 입력값으로 (batch_size, 100) 형상의 노이즈 벡터를 받습니다.
#
#
#
# **처음 입력된 벡터는 어떤 레이어를 지나며, 첫 레이어를 지난 후의 shape는 어떤 형태입니까?**
# >(batch_size, 100) 벡터 -> 7 x 7 x 256 = 12544개의 노드를 가진 첫 번째 Dense 레이어 -> (batch_size, 12544) 형상의 벡터
#
#
#
# **첫 번째 레이어를 지난 후 벡터는 어떤 층을 지나게 됩니까? 이 레이어는 왜 필요합니까?**
# >Reshape layer
# 차원 벡터를 (7, 7, 256) 형상의 3차원 벡터로 변환하기 위해서

# %%
generator = make_generator_model()

generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 49152)             4915200
# _________________________________________________________________
# batch_normalization (BatchNo (None, 49152)             196608
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 49152)             0
# _________________________________________________________________
# reshape (Reshape)            (None, 8, 8, 768)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 8, 8, 384)         7372800
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8, 8, 384)         1536
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 8, 8, 384)         0
# ...

# %% [markdown]
# ## noise = tf.random.normal([1, 100])로 생성된 랜덤 노이즈를 입력으로 하여 방금 구현한 생성자로 랜덤 이미지를 생성해 봅시다.

# %%
noise = tf.random.normal([1, 100])
noise
# Out:
# <tf.Tensor: shape=(1, 100), dtype=float32, numpy=
# array([[-1.2756981 ,  1.5098902 ,  0.0906315 ,  0.29520476,  0.11160053,
#          0.12542506, -0.82780266, -3.1684158 ,  2.167122  , -1.2107925 ,
#         -0.7454072 , -0.52711046,  0.04980409, -1.6528102 ,  0.55710644,
#          0.39276952,  0.7825173 , -0.48669937,  0.09338318, -0.5031433 ,
#         -0.42405397,  0.8179931 ,  0.89924777, -0.6584393 ,  0.2742655 ,
#         -0.9029563 , -1.1777129 ,  1.110347  ,  0.4248258 ,  0.29981914,
#         -0.1338977 , -1.300023  ,  0.5889885 ,  1.3196818 ,  1.7131397 ,
#         -0.5302799 ,  0.5103509 , -0.0241344 , -0.12985857,  1.3389322 ,
#         -0.35210282,  0.54399335,  0.7659988 , -0.4272501 ,  0.22196047,
#         -0.11606932, -1.2779028 , -1.8470263 ,  0.04405003,  0.17249615,
#          0.74448633, -0.50699425, -0.3996698 ,  1.6121358 , -2.2065206 ,
#         -0.46066082,  0.05994751,  1.3831325 ,  1.0929755 , -0.55198103,
# ...

# %%
generated_image = generator(noise, training=False)
generated_image.shape
# Out:
# TensorShape([1, 32, 32, 3])

# %% [markdown]
# ## 생성된 랜덤 이미지가 생성자 출력 규격에 잘 맞는지 확인해 봅시다.

# %%
plt.imshow(generated_image[0, :, :, 0], cmap='gray')
plt.colorbar()
plt.show()

# %%
plt.imshow(generated_image[0, :, :, 0])
plt.colorbar()
plt.show()

# %%
# plt.imshow(predictions[i] * 0.5 + 0.5)
# plt.imshow(generated_image[0] * 0.5 + 0.5) # 개구리처럼 보인다 왜 이게 잘나오는 걸까
plt.imshow(generated_image[0])
plt.colorbar()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# #  STEP 3. 판별자 모델 구현하기

# %% [markdown]
# - 32, 32, 3)의 이미지를 입력으로 받아 1dim을 판별결과를 출력하는 판별자 모델 구현 함수를 작성해 봅시다.
# - 위 STEP 2에서 생성한 랜덤 이미지를 판별자 모델이 판별한 결과값을 확인해 봅시다.

# %% [markdown]
# ## (32, 32, 3)의 이미지를 입력으로 받아 1dim을 판별결과를 출력하는 판별자 모델 구현 함수를 작성해 봅시다.

# %%
def make_discriminator_model():

    # Start
    model = tf.keras.Sequential()

    # First: Conv2D Layer
    model.add(layers.Conv2D(192, (5, 5), strides=(2, 2), padding='same', input_shape=[32, 32, 3]))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    # Second: Conv2D Layer
    model.add(layers.Conv2D(768, (5, 5), strides=(2, 2), padding='same'))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    # Third: Flatten Layer
    model.add(layers.Flatten())

    # Fourth: Dense Layer
    model.add(layers.Dense(1))

    return model

# %% [markdown]
# 판별자도 함수로 구현함
#
# **함수 내부**
# * 판별자는 Conv2D 층으로 이미지의 크기를 점점 줄여나갑니다
#   첫 번째 Conv2D 층에서 입력된 \[32, 32, 3\] 사이즈의 이미지는 다음 층을 거치며 (32, 32, 768) → (16, 16, 192) → (8, 8, 768)까지
# * Flatten 층을 사용해 3차원 이미지를 1차원으로 쭉 펴서 8x8x768=49152, 즉 (1, 49152) 형상의 벡터로 변환
# * 마지막 Dense Layer를 거쳐 단 하나의 값을 출력

# %%
discriminator = make_discriminator_model()

discriminator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 16, 16, 192)       14592
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 16, 16, 192)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 192)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 768)         3687168
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 8, 8, 768)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 768)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 49152)             0
# ...

# %% [markdown]
# ## 위 STEP 2에서 생성한 랜덤 이미지를 판별자 모델이 판별한 결과값을 확인해 봅시다.

# %%
decision = discriminator(generated_image, training=False)
decision
# Out:
# <tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[0.00120562]], dtype=float32)>

# %%
decision = discriminator(generated_image, training=False)
decision.shape
# Out:
# TensorShape([1, 1])

# %% [markdown]
# # STEP 4. 손실함수와 최적화 함수 구현하기

# %% [markdown]
# - 생성자와 판별자의 손실함수(loss)를 구현해 봅시다.
# - 판별자의 출력값을 가지고 실제/생성(real/fake) 이미지 판별 정확도(accuracy)를 계산하는 함수를 구현해 봅시다.
# - 생성자와 판별자를 최적화하는 optimizer를 정의합니다.

# %% [markdown]
# ## 생성자와 판별자의 손실함수(loss)를 구현해 봅시다.

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %% [markdown]
# **생성자 손실함수**

# %%
def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %% [markdown]
# **판별자 손실함수**

# %%
def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

# %% [markdown]
# ## 판별자의 출력값을 가지고 실제/생성(real/fake) 이미지 판별 정확도(accuracy)를 계산하는 함수를 구현해 봅시다.

# %%
def discriminator_accuracy(real_output, fake_output):
    real_accuracy = tf.reduce_mean(tf.cast(tf.math.greater_equal(real_output, tf.constant([0.5])), tf.float32))
    fake_accuracy = tf.reduce_mean(tf.cast(tf.math.less(fake_output, tf.constant([0.5])), tf.float32))
    return real_accuracy, fake_accuracy

# %% [markdown]
# 예를 들어 위의 코드를 설명
# ex.) real_output = tf.Tensor(\[0.2, 0.4, 0.7, 0.9]) 라면,
#
# (1) tf.math.greater_equal(real_output, tf.constant([0.5]) : real_output의 각 원소가 0.5 이상인지 True, False로 판별
# > tf.Tensor([False, False, True, True])
#
# (2) tf.cast( (1), tf.float32) : (1)의 결과가 True이면 1.0, False이면 0.0으로 변환
# > tf.Tensor([0.0, 0.0, 1.0, 1.0])
#
# (3) tf.reduce_mean( (2)) : (2)의 결과를 평균내어 이번 배치의 정확도(accuracy)를 계산
# > 0.5

# %% [markdown]
# ## 생성자와 판별자를 최적화하는 optimizer를 정의합니다.

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# %% [markdown]
# ## 16개의 고정된 seed

# %%
noise_dim = 100
num_examples_to_generate = 16

seed = tf.random.normal([num_examples_to_generate, noise_dim])
seed.shape
# Out:
# TensorShape([16, 100])

# %% [markdown]
# # ?? STEP 5. 훈련과정 상세 기능 구현하기

# %% [markdown]
# - 1개 미니배치의 훈련 과정을 처리하는 train_step() 함수를 구현해 봅시다.
# - 16개의 고정된 seed를 입력으로 하여 훈련 과정 동안 생성한 이미지를 시각화하는 generate_and_save_images() 함수를 구현해 봅시다.
# - 훈련 epoch마다 생성자/판별자의 loss 및 판별자의 실제/생성(real/fake) 이미지 판별 accuracy 히스토리(history)를 그래프로 시각화하는 draw_train_history() 함수를 구현해 봅시다.
# - training_checkpoints 디렉토리에 몇 epoch마다 모델을 저장하는 checkpoint 모듈을 설정해 봅시다.

# %% [markdown]
# ## 1개 미니배치의 훈련 과정을 처리하는 train_step() 함수를 구현해 봅시다.

# %%
@tf.function
def train_step(images):  #(1) 입력데이터
    noise = tf.random.normal([BATCH_SIZE, noise_dim])  #(2) 생성자 입력 노이즈

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:  #(3) tf.GradientTape() 오픈
        generated_images = generator(noise, training=True)  #(4) generated_images 생성

        #(5) discriminator 판별
        real_output = discriminator(images, training=True)
        fake_output = discriminator(generated_images, training=True)

        #(6) loss 계산
        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

        #(7) accuracy 계산
        real_accuracy, fake_accuracy = discriminator_accuracy(real_output, fake_output) 
    
    #(8) gradient 계산
    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    #(9) 모델 학습
    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return gen_loss, disc_loss, real_accuracy, fake_accuracy  #(10) 리턴값

# %% [markdown]
# train_step 함수를 하나하나 뜯어보면 다음과 같습니다.
#
# >(1) 입력데이터: Real Image 역할을 할 images 한 세트를 입력으로 받음
# (2) 생성자 입력 노이즈 : generator가 FAKE IMAGE를 생성하기 위한 noise를 images 한 세트와 같은 크기인 BATCH_SIZE 만큼 생성함
# (3) tf.GradientTape()는 가중치 갱신을 위한 Gradient를 자동 미분으로 계산하기 위해 with 구문 열기
# (4) generated_images 생성 : generator가 noise를 입력받은 후 generated_images 생성
# (5) discriminator 판별 : discriminator가 Real Image인 images와 Fake Image인 generated_images를 각각 입력받은 후 real_output, fake_output 출력
# (6) loss 계산 : fake_output, real_output으로 generator와 discriminator 각각의 loss 계산
# (7) accuracy 계산 : fake_output, real_output으로 discriminator가
# (8) gradient 계산 : gen_tape와 disc_tape를 활용해 gradient를 자동으로 계산
# (9) 모델 학습 : 계산된 gradient를 optimizer에 입력해 가중치 갱신
# (10) 리턴값 : 이번 스텝에 계산된 loss와 accuracy를 리턴

# %% [markdown]
# ## 16개의 고정된 seed를 입력으로 하여 훈련 과정 동안 생성한 이미지를 시각화하는 generate_and_save_images() 함수를 구현해 봅시다.

# %%
def generate_and_save_images(model, epoch, it, sample_seeds):

    predictions = model(sample_seeds, training=False)

    fig = plt.figure(figsize=(4, 4))
    for i in range(predictions.shape[0]):
        plt.subplot(4, 4, i+1)
        plt.imshow(predictions[i, :, :, 0], cmap='gray')
        plt.axis('off')

    plt.savefig('{}/aiffel/dcgan_newimage/cifar10/generated_samples/sample_epoch_{:04d}_iter_{:03d}.png'
                    .format(os.getenv('HOME'), epoch, it))

    plt.show()

# %% [markdown]
# ## 훈련 epoch마다 생성자/판별자의 loss 및 판별자의 실제/생성(real/fake) 이미지 판별 accuracy 히스토리(history)를 그래프로 시각화하는 draw_train_history() 함수를 구현해 봅시다.

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6    # matlab 차트의 기본 크기를 15,6으로 지정해 줍니다.

def draw_train_history(history, epoch):
    # summarize history for loss  
    plt.subplot(211)  
    plt.plot(history['gen_loss'])  
    plt.plot(history['disc_loss'])  
    plt.title('model loss')  
    plt.ylabel('loss')  
    plt.xlabel('batch iters')  
    plt.legend(['gen_loss', 'disc_loss'], loc='upper left')  

    # summarize history for accuracy  
    plt.subplot(212)  
    plt.plot(history['fake_accuracy'])  
    plt.plot(history['real_accuracy'])  
    plt.title('discriminator accuracy')  
    plt.ylabel('accuracy')  
    plt.xlabel('batch iters')  
    plt.legend(['fake_accuracy', 'real_accuracy'], loc='upper left')  
    
    # training_history 디렉토리에 epoch별로 그래프를 이미지 파일로 저장합니다.
    plt.savefig('{}/aiffel/dcgan_newimage/cifar10/training_history/train_history_{:04d}.png'
                    .format(os.getenv('HOME'), epoch))
    plt.show()

# %% [markdown]
# ## training_checkpoints 디렉토리에 몇 epoch마다 모델을 저장하는 checkpoint 모듈을 설정해 봅시다.

# %%
checkpoint_dir = os.getenv('HOME')+'/aiffel/dcgan_newimage/cifar10/training_checkpoints'

checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

# %% [markdown]
# # STEP 6. 학습 과정 진행하기

# %% [markdown]
# - 위 STEP 5에서 구현한 기능들을 활용하여 최소 50 epoch만큼의 모델 학습을 진행해 봅시다.
# - 학습 과정에서 생성된 샘플 이미지로 만든 gif 파일을 통해 학습 진행 과정을 시각적으로 표현해 봅시다.
# - 학습 과정을 담은 샘플 이미지, gif 파일, 학습 진행 그래프 이미지를 함께 제출합니다.
#
# 여기서 epoch을 추가 진행할때 위에서 checkpoint 모듈을 이용해 모델을 저장해놨는데
# 학습해 둔 모델을 로드하면 모델 재학습이 필요 없이 이런 작업을 진행할 수 있다
# 아래는 checkpoint 모듈을 활용하여 모델을 로드하는 예시

# %%
checkpoint_dir = os.getenv('HOME')+'/aiffel/dcgan_newimage/cifar10/training_checkpoints'

latest = tf.train.latest_checkpoint(checkpoint_dir)
checkpoint.restore(latest)

generator = checkpoint.generator
discriminator = checkpoint.discriminator

# 로드한 모델이 정상적으로 이미지를 생성하는지 확인해 봅니다. 
noise = tf.random.normal([1, 100])
generated_image = generator(noise, training=False)

np_generated = generated_image.numpy()
np_generated = (np_generated * 127.5) + 127.5   # reverse of normalization
np_generated = np_generated.astype(int)
plt.imshow(np_generated[0])
plt.show()  # 정상적으로 모델이 로드되었다면 랜덤 이미지가 아니라 CIFAR-10 이미지가 그려질 것입니다.

# %%
def train(dataset, epochs, save_every):
    start = time.time()
    history = {'gen_loss':[], 'disc_loss':[], 'real_accuracy':[], 'fake_accuracy':[]}

    for epoch in range(epochs):
        epoch_start = time.time()
        for it, image_batch in enumerate(dataset):
            gen_loss, disc_loss, real_accuracy, fake_accuracy = train_step(image_batch)
            history['gen_loss'].append(gen_loss)
            history['disc_loss'].append(disc_loss)
            history['real_accuracy'].append(real_accuracy)
            history['fake_accuracy'].append(fake_accuracy)

            if it % 50 == 0:
                display.clear_output(wait=True)
                generate_and_save_images(generator, epoch+1, it+1, seed)
                print('Epoch {} | iter {}'.format(epoch+1, it+1))
                print('Time for epoch {} : {} sec'.format(epoch+1, int(time.time()-epoch_start)))

        if (epoch + 1) % save_every == 0:
            checkpoint.save(file_prefix=checkpoint_prefix)

        display.clear_output(wait=True)
        generate_and_save_images(generator, epochs, it, seed)
        print('Time for training : {} sec'.format(int(time.time()-start)))

        draw_train_history(history, epoch)

# %%
save_every = 5
EPOCHS = 50

# 사용가능한 GPU 디바이스 확인
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 위 STEP 5에서 구현한 기능들을 활용하여 최소 50 epoch만큼의 모델 학습을 진행해 봅시다.

# %%
# %%time
train(train_dataset, EPOCHS, save_every)
# 21:45~22:41

# 학습과정의 loss, accuracy 그래프 이미지 파일이 ~/aiffel/dcgan_newimage/cifar10/training_history 경로에 생성되고 있으니
# 진행 과정을 수시로 확인해 보시길 권합니다.
# Out:
# Time for training : 3573 sec
# CPU times: user 58min 54s, sys: 32.5 s, total: 59min 27s
# Wall time: 59min 34s

# %% [markdown]
# ## 학습 과정에서 생성된 샘플 이미지로 만든 gif 파일을 통해 학습 진행 과정을 시각적으로 표현해 봅시다.

# %%
anim_file = os.getenv('HOME')+'/aiffel/dcgan_newimage/cifar10/cifar_10_dcgan_grayscale.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
    filenames = glob.glob('{}/aiffel/dcgan_newimage/cifar10/generated_samples/sample*.png'.format(os.getenv('HOME')))
    filenames = sorted(filenames)
    last = -1
    for i, filename in enumerate(filenames):
        frame = 2*(i**0.5)
        if round(frame) > round(last):
            last = frame
        else:
            continue
        image = imageio.imread(filename)
        writer.append_data(image)
    image = imageio.imread(filename)
    writer.append_data(image)

# !ls -l ~/aiffel/dcgan_newimage/cifar10/cifar_10_dcgan_grayscale.gif
# Out:
# -rw-r--r-- 1 aiffel-dj35 aiffel-dj35 2148112  3월  2 12:58 /home/aiffel-dj35/aiffel/dcgan_newimage/cifar10/cifar_10_dcgan_grayscale.gif

# %% [markdown]
# # STEP 7. (optional) GAN 훈련 과정 개선하기

# %% [markdown]
# ## 컬러로 바꾸기
# - 6.2단계 수정 : 흑백으로 나왔다 -> 컬러로 바꾸자
# 참고 : https://colab.research.google.com/drive/1NWUrPJLLVvA-THpv2XqEgYeemuFl3Qj-#scrollTo=RmdVsmvhPxyy

# %%
predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-fd2951b82103> in <module>
# ----> 1 predictions
#
# NameError: name 'predictions' is not defined

# %%
predictions[i]

# %%
predictions.shape

# %%
def generate_and_save_images(model, epoch, it, sample_seeds):

    predictions = model(sample_seeds, training=False)

    fig = plt.figure(figsize=(4, 4))
    for i in range(predictions.shape[0]):
        plt.subplot(4, 4, i+1)
#         plt.imshow(predictions[i, :, :, 0], cmap='gray')
        plt.imshow(predictions[i] * 0.5 + 0.5) # rgb로 바꾸기 위해 변경
        plt.axis('off')

    plt.savefig('{}/aiffel/dcgan_newimage/cifar10/generated_samples/sample_epoch_{:04d}_iter_{:03d}.png'
                    .format(os.getenv('HOME'), epoch, it))

    plt.show()

# %%
save_every = 5
EPOCHS = 5

# 사용가능한 GPU 디바이스 확인
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# %%time
train(train_dataset, EPOCHS, save_every)
# 22:44~22:49

# 학습과정의 loss, accuracy 그래프 이미지 파일이 ~/aiffel/dcgan_newimage/cifar10/training_history 경로에 생성되고 있으니
# 진행 과정을 수시로 확인해 보시길 권합니다.
# Out:
# Time for training : 349 sec
# CPU times: user 5min 48s, sys: 2.45 s, total: 5min 50s
# Wall time: 5min 50s

# %%
anim_file = os.getenv('HOME')+'/aiffel/dcgan_newimage/cifar10/cifar_10_dcgan_epoch_55_re.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
    filenames = glob.glob('{}/aiffel/dcgan_newimage/cifar10/generated_samples/sample*.png'.format(os.getenv('HOME')))
    filenames = sorted(filenames)
    last = -1
    for i, filename in enumerate(filenames):
        frame = 2*(i**0.5)
        if round(frame) > round(last):
            last = frame
        else:
            continue
        image = imageio.imread(filename)
        writer.append_data(image)
    image = imageio.imread(filename)
    writer.append_data(image)

# !ls -l ~/aiffel/dcgan_newimage/cifar10/cifar_10_dcgan_epoch_55_re.gif
# Out:
# -rw-r--r-- 1 aiffel-dj35 aiffel-dj35 2145904  3월  2 13:15 /home/aiffel-dj35/aiffel/dcgan_newimage/cifar10/cifar_10_dcgan_epoch_55_re.gif

# %% [markdown]
# ## 초기화 후 epochs = 100

# %%
def re_generate_and_save_images(model, epoch, it, sample_seeds):

    predictions = model(sample_seeds, training=False)

    fig = plt.figure(figsize=(7,7))
    for i in range(predictions.shape[0]):
        plt.subplot(4, 4, i+1)
        plt.imshow(predictions[i] * 0.5 + 0.5) # rgb로 바꾸기 위해 변경
        plt.axis('off')

    plt.savefig('{}/aiffel/dcgan_newimage/cifar10/re_generated_samples/sample_epoch_{:04d}_iter_{:03d}.png'
                    .format(os.getenv('HOME'), epoch, it))

    plt.show()

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 10    # matlab 차트의 기본 크기

def re_draw_train_history(history, epoch):
    # summarize history for loss  
    plt.subplot(211)  
    plt.plot(history['gen_loss'])  
    plt.plot(history['disc_loss'])  
    plt.title('model loss')  
    plt.ylabel('loss')  
    plt.xlabel('batch iters')  
    plt.legend(['gen_loss', 'disc_loss'], loc='upper left')  

    # summarize history for accuracy  
    plt.subplot(212)  
    plt.plot(history['fake_accuracy'])  
    plt.plot(history['real_accuracy'])  
    plt.title('discriminator accuracy')  
    plt.ylabel('accuracy')  
    plt.xlabel('batch iters')  
    plt.legend(['fake_accuracy', 'real_accuracy'], loc='upper left')  
    
    # training_history 디렉토리에 epoch별로 그래프를 이미지 파일로 저장합니다.
    plt.savefig('{}/aiffel/dcgan_newimage/cifar10/re_training_history/train_history_{:04d}.png'
                    .format(os.getenv('HOME'), epoch))
    plt.show()

# %%
checkpoint_dir = os.getenv('HOME')+'/aiffel/dcgan_newimage/cifar10/re_training_checkpoints'

checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

# %%
checkpoint_dir = os.getenv('HOME')+'/aiffel/dcgan_newimage/cifar10/re_training_checkpoints'

latest = tf.train.latest_checkpoint(checkpoint_dir)
checkpoint.restore(latest)

generator = checkpoint.generator
discriminator = checkpoint.discriminator

# 로드한 모델이 정상적으로 이미지를 생성하는지 확인해 봅니다. 
noise = tf.random.normal([1, 100])
generated_image = generator(noise, training=False)

np_generated = generated_image.numpy()
np_generated = (np_generated * 127.5) + 127.5   # reverse of normalization
np_generated = np_generated.astype(int)
plt.imshow(np_generated[0])
plt.show()  # 정상적으로 모델이 로드되었다면 랜덤 이미지가 아니라 CIFAR-10 이미지가 그려질 것입니다.

# %%
@tf.function
def train_step(images):  #(1) 입력데이터
    noise = tf.random.normal([BATCH_SIZE, noise_dim])  #(2) 생성자 입력 노이즈

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:  #(3) tf.GradientTape() 오픈
        generated_images = generator(noise, training=True)  #(4) generated_images 생성

        #(5) discriminator 판별
        real_output = discriminator(images, training=True)
        fake_output = discriminator(generated_images, training=True)

        #(6) loss 계산
        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

        #(7) accuracy 계산
        real_accuracy, fake_accuracy = discriminator_accuracy(real_output, fake_output) 
    
    #(8) gradient 계산
    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    #(9) 모델 학습
    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return gen_loss, disc_loss, real_accuracy, fake_accuracy  #(10) 리턴값

# %%
def train(dataset, epochs, save_every):
    start = time.time()
    history = {'gen_loss':[], 'disc_loss':[], 'real_accuracy':[], 'fake_accuracy':[]}

    for epoch in range(epochs):
        epoch_start = time.time()
        for it, image_batch in enumerate(dataset):
            gen_loss, disc_loss, real_accuracy, fake_accuracy = train_step(image_batch)
            history['gen_loss'].append(gen_loss)
            history['disc_loss'].append(disc_loss)
            history['real_accuracy'].append(real_accuracy)
            history['fake_accuracy'].append(fake_accuracy)

            if it % 50 == 0:
                display.clear_output(wait=True)
                re_generate_and_save_images(generator, epoch+1, it+1, seed)
                print('Epoch {} | iter {}'.format(epoch+1, it+1))
                print('Time for epoch {} : {} sec'.format(epoch+1, int(time.time()-epoch_start)))

        if (epoch + 1) % save_every == 0:
            checkpoint.save(file_prefix=checkpoint_prefix)

        display.clear_output(wait=True)
        re_generate_and_save_images(generator, epochs, it, seed)
        print('Time for training : {} sec'.format(int(time.time()-start)))

        re_draw_train_history(history, epoch)

# %%
save_every = 5
EPOCHS = 10

# 사용가능한 GPU 디바이스 확인
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# %%time
train(train_dataset, EPOCHS, save_every)

# 학습과정의 loss, accuracy 그래프 이미지 파일이 ~/aiffel/dcgan_newimage/cifar10/training_history 경로에 생성되고 있으니
# 진행 과정을 수시로 확인해 보시길 권합니다.
# Out:
# Time for training : 723 sec
# CPU times: user 11min 59s, sys: 4.58 s, total: 12min 4s
# Wall time: 12min 3s

# %% [markdown]
# ## 컬러로 에폭 50

# %%
anim_file = os.getenv('HOME')+'/aiffel/dcgan_newimage/cifar10/cifar_10_dcgan_epoch_10.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
    filenames = glob.glob('{}/aiffel/dcgan_newimage/cifar10/re_generated_samples/sample*.png'.format(os.getenv('HOME')))
    filenames = sorted(filenames)
    last = -1
    for i, filename in enumerate(filenames):
        frame = 2*(i**0.5)
        if round(frame) > round(last):
            last = frame
        else:
            continue
        image = imageio.imread(filename)
        writer.append_data(image)
    image = imageio.imread(filename)
    writer.append_data(image)

# !ls -l ~/aiffel/dcgan_newimage/cifar10/cifar_10_dcgan_epoch_10.gif
# Out:
# -rw-r--r-- 1 aiffel-dj35 aiffel-dj35 3319857  3월  2 16:29 /home/aiffel-dj35/aiffel/dcgan_newimage/cifar10/cifar_10_dcgan_epoch_10.gif

# %%
save_every = 5
EPOCHS = 50

# 사용가능한 GPU 디바이스 확인
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# %%time
train(train_dataset, EPOCHS, save_every)

# 학습과정의 loss, accuracy 그래프 이미지 파일이 ~/aiffel/dcgan_newimage/cifar10/training_history 경로에 생성되고 있으니
# 진행 과정을 수시로 확인해 보시길 권합니다.
# Out:
# Time for training : 3640 sec
# CPU times: user 1h 18s, sys: 23.7 s, total: 1h 41s
# Wall time: 1h 41s

# %%
anim_file = os.getenv('HOME')+'/aiffel/dcgan_newimage/cifar10/cifar_10_dcgan_epoch_50.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
    filenames = glob.glob('{}/aiffel/dcgan_newimage/cifar10/re_generated_samples/sample*.png'.format(os.getenv('HOME')))
    filenames = sorted(filenames)
    last = -1
    for i, filename in enumerate(filenames):
        frame = 2*(i**0.5)
        if round(frame) > round(last):
            last = frame
        else:
            continue
        image = imageio.imread(filename)
        writer.append_data(image)
    image = imageio.imread(filename)
    writer.append_data(image)

# !ls -l ~/aiffel/dcgan_newimage/cifar10/cifar_10_dcgan_epoch_50.gif
# Out:
# -rw-r--r-- 1 aiffel-dj35 aiffel-dj35 3319857  3월  2 16:25 /home/aiffel-dj35/aiffel/dcgan_newimage/cifar10/cifar_10_dcgan_epoch_50.gif

# %% [markdown]
# <흑백&컬러 에폭 50> ![cifar_10_dcgan_epoch_55.gif](https://phinf.pstatic.net/memo/20210302_249/1614692077721zoWsC_GIF/cifar_10_dcgan_epoch_55.gif)

# %% [markdown]
# <컬러로만 에폭 50> ![cifar_10_dcgan_epoch_50.gif](https://phinf.pstatic.net/memo/20210302_33/1614692071619oG2AO_GIF/cifar_10_dcgan_epoch_50.gif)

# %% [markdown]
# ## learning rate 변경

# %%
# learning rate 변경 0.0001 -> 0.001
generator_optimizer = tf.keras.optimizers.Adam(1e-3)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-3)

# %%
def re_generate_and_save_images(model, epoch, it, sample_seeds):

    predictions = model(sample_seeds, training=False)

    fig = plt.figure(figsize=(7,7))
    for i in range(predictions.shape[0]):
        plt.subplot(4, 4, i+1)
        plt.imshow(predictions[i] * 0.5 + 0.5) # rgb로 바꾸기 위해 변경
        plt.axis('off')

    plt.savefig('{}/aiffel/dcgan_newimage/cifar10/re_generated_samples/chng_lr_sample_epoch_{:04d}_iter_{:03d}.png'
                    .format(os.getenv('HOME'), epoch, it))

    plt.show()

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 10    # matlab 차트의 기본 크기

def re_draw_train_history(history, epoch):
    # summarize history for loss  
    plt.subplot(211)  
    plt.plot(history['gen_loss'])  
    plt.plot(history['disc_loss'])  
    plt.title('model loss')  
    plt.ylabel('loss')  
    plt.xlabel('batch iters')  
    plt.legend(['gen_loss', 'disc_loss'], loc='upper left')  

    # summarize history for accuracy  
    plt.subplot(212)  
    plt.plot(history['fake_accuracy'])  
    plt.plot(history['real_accuracy'])  
    plt.title('discriminator accuracy')  
    plt.ylabel('accuracy')  
    plt.xlabel('batch iters')  
    plt.legend(['fake_accuracy', 'real_accuracy'], loc='upper left')  
    
    # training_history 디렉토리에 epoch별로 그래프를 이미지 파일로 저장합니다.
    plt.savefig('{}/aiffel/dcgan_newimage/cifar10/re_training_history/chng_lr_train_history_{:04d}.png'
                    .format(os.getenv('HOME'), epoch))
    plt.show()

# %%
@tf.function
def train_step(images):  #(1) 입력데이터
    noise = tf.random.normal([BATCH_SIZE, noise_dim])  #(2) 생성자 입력 노이즈

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:  #(3) tf.GradientTape() 오픈
        generated_images = generator(noise, training=True)  #(4) generated_images 생성

        #(5) discriminator 판별
        real_output = discriminator(images, training=True)
        fake_output = discriminator(generated_images, training=True)

        #(6) loss 계산
        gen_loss = generator_loss(fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

        #(7) accuracy 계산
        real_accuracy, fake_accuracy = discriminator_accuracy(real_output, fake_output) 
    
    #(8) gradient 계산
    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    #(9) 모델 학습
    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return gen_loss, disc_loss, real_accuracy, fake_accuracy  #(10) 리턴값

# %%
def train(dataset, epochs, save_every):
    start = time.time()
    history = {'gen_loss':[], 'disc_loss':[], 'real_accuracy':[], 'fake_accuracy':[]}

    for epoch in range(epochs):
        epoch_start = time.time()
        for it, image_batch in enumerate(dataset):
            gen_loss, disc_loss, real_accuracy, fake_accuracy = train_step(image_batch)
            history['gen_loss'].append(gen_loss)
            history['disc_loss'].append(disc_loss)
            history['real_accuracy'].append(real_accuracy)
            history['fake_accuracy'].append(fake_accuracy)

            if it % 50 == 0:
                display.clear_output(wait=True)
                re_generate_and_save_images(generator, epoch+1, it+1, seed)
                print('Epoch {} | iter {}'.format(epoch+1, it+1))
                print('Time for epoch {} : {} sec'.format(epoch+1, int(time.time()-epoch_start)))

        if (epoch + 1) % save_every == 0:
            checkpoint.save(file_prefix=checkpoint_prefix)

        display.clear_output(wait=True)
        re_generate_and_save_images(generator, epochs, it, seed)
        print('Time for training : {} sec'.format(int(time.time()-start)))

        re_draw_train_history(history, epoch)

# %%
save_every = 5
EPOCHS = 50

# 사용가능한 GPU 디바이스 확인
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# %%time
train(train_dataset, EPOCHS, save_every)
# Out:
# Time for training : 3441 sec
# CPU times: user 57min 4s, sys: 24.7 s, total: 57min 29s
# Wall time: 57min 22s

# %%
anim_file = os.getenv('HOME')+'/aiffel/dcgan_newimage/cifar10/chng_lr_cifar_10_dcgan_epoch_50.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
    filenames = glob.glob('{}/aiffel/dcgan_newimage/cifar10/chng_lr_generated_samples/chng*.png'.format(os.getenv('HOME')))
    filenames = sorted(filenames)
    last = -1
    for i, filename in enumerate(filenames):
        frame = 2*(i**0.5)
        if round(frame) > round(last):
            last = frame
        else:
            continue
        image = imageio.imread(filename)
        writer.append_data(image)
    image = imageio.imread(filename)
    writer.append_data(image)

# !ls -l ~/aiffel/dcgan_newimage/cifar10/chng_lr_cifar_10_dcgan_epoch_50.gif
# Out:
# -rw-r--r-- 1 aiffel-dj35 aiffel-dj35 3406113  3월  3 00:06 /home/aiffel-dj35/aiffel/dcgan_newimage/cifar10/chng_lr_cifar_10_dcgan_epoch_50.gif

# %% [markdown]
# ![lr=0.001](https://phinf.pstatic.net/memo/20210303_158/1614697648590NHx2U_GIF/chng_lr_cifar_10_dcgan_epoch_50.gif)

# %% [markdown]
# 너무 이상하다 그래프도 이상하고 이미지도 많이 이상하다.
# -> learning rate를 10배 이상 올리는 것은 무모했구나

# %% [markdown]
# # Study

# %% [markdown]
# + 많고 많은 생성 모델 중에서
#   GAN (Generative Adversarial Network)
# + 두 개의 네트워크가 경쟁하듯 만들어진 모델이어서 Adversarial(적대적인)이 들어감
# + 특히 합성곱 층(Convolutional Layer)으로 이루어진 딥러닝 모델을 DCGAN(Deep Convolutional GAN) 이라고 함
# ![](https://openai.com/content/images/2017/02/gen_models_diag_1.svg)

# %% [markdown]
# + 100개의 난수를 64\*64\*3으로 출력
# + DCGAN 모델 구현은 Keras Sequential API를 활용
# + 세 번의 Conv2DTranspose 층을 이용해 (8, 8, 768) → (16, 16, 192) → (32, 32, 3) 순으로 이미지를 키워나가게 했는데
#   다른 사람들과도 비교해보고 싶다
#   다시 돌릴 시간과 인내심이 주어진다면 (8, 8, 256) → (16, 16, 128) → (32, 32, 3) 로 해도 파라미터 적게 가능했을 것으로 보인다
# + batchnormalization으로 가중치값을 정규화해서 무한대로 커지는 것을 막았는데
#   -> cs231n수업에서 이해가 아직 안됐어서,,,, 1번으로 공부해야겠다
# + 중간층들의 활성화 함수는 모두 LeakyReLU를 사용
# + 마지막 층에서는 tanh를 사용하는데, -1 ~ 1 이내의 값으로 픽셀값을 정규화시켰던 데이터셋과 동일하게 하기 위함
# ![](https://mathworld.wolfram.com/images/interactive/TanhReal.gif)

# %% [markdown]
# + reshape 층에서 입력 벡터를 3차원으로 변환한다
# + generator 생성자 모델 출력은 shape은 TensorShape(\[1, 28, 28, 1\]) 이렇게 나오는데
#   첫번째 1 -> batch_size=1
#   (28, 28, 1) -> 이 사이즈의 이미지가 생성되었다는 뜻
#
# + 이렇게 만든 이미지를 matplotlib으로 출력할 때
#   -> 2차원밖에 출력이 안되니까 맨 앞과 맨 뒤의 1의 인덱스를 0으로 설정해서 출력
#   -> 근데 0으로 안해도 잘 나오던데 -> Why???
#
# + discriminator 판별자 모델 출력도 생성자 출력과 동일하게 텐서플로우의 텐서 형태로 출력 되는데
#   나는 그 tensor shape을 모르더라... 어휴 -> 텐서 쉐입이란 ???
#   ***
# + 여기까지가 모델을 함수 형태로 만든거고
#   이제는 학습을 시킬 함수를 만들어야 함
#   ***
#
# +
# ![SmartSelect_20210302-214006_Samsung%20Notes-2.jpg](https://phinf.pstatic.net/memo/20210302_116/1614692091804py7bG_JPEG/SmartSelect_20210302-214006_Samsung_Notes.jpg?type=w740)

# %% [markdown]
# ![SmartSelect_20210302-213941_Samsung%20Notes.jpg](https://phinf.pstatic.net/memo/20210302_67/1614692087433uxyYI_JPEG/SmartSelect_20210302-213941_Samsung_Notes.jpg?type=w740)

# %% [markdown]
# + 두번째로 필요한 함수는 최적화 함수 Adam을 쓰고, learning rate를 바꿔 가면서 학습을 진행해보자
# + 학습을 따로 시키니까 각각 지정해줘야 함
# + 고정된 seed 노이즈 부분 이해안감 -> ???
# + @tf.function 데코레이터가 사용된 함수에 입력된 입력은 Tensorflow의 graph 노드가 될 수 있는 타입으로 자동변환
#   ->이해 잘 안가지만 일단 외우자 -> ???

# %% [markdown]
# + 모델을 학습시킬 train_step함수 코드는 결국 정확도, loss로 그래프 그리고
#   loss로 gradient 계산해서 최적화함수(optimizer)로 가중치 갱신

# %% [markdown]
# # 보충 필요

# %% [markdown]
# ```
#         plt.imshow(predictions[i, :, :, 0], cmap='gray')
#         plt.imshow(predictions[i] * 0.5 + 0.5) # rgb로 바꾸기 위해 변경
# ```
# 잘 이해가 가지 않는다
# 프리딕션 안에 인자가 4개 있었는데
# 이거를 어떻게 한개로 줄이고 계산을 했는지,
# 프리딕션을 확인하고 싶은데 확인할 수 없을까?

# %% [markdown]
# + 이렇게 만든 이미지를 matplotlib으로 출력할 때
#   -> 2차원밖에 출력이 안되니까 맨 앞과 맨 뒤의 1의 인덱스를 0으로 설정해서 출력
#   -> 근데 0으로 안해도 잘 나오던데 -> Why???

# %% [markdown]
# + tensor shape이란???

# %% [markdown]
# 고정된 seed 노이즈 부분 이해안감 -> 어떤 과정인건지???

# %% [markdown]
# learning rate 복습

# %% [markdown]
# # 루브릭

# %% [markdown]
# 평가문항	상세기준
# 1. GAN의 두 모델 구조를 통해 이미지를 성공적으로 생성하였다.
#    오브젝트 종류를 육안으로 구별할 수 있을 만한 이미지를 생성하였다.
#    -> (2, 4) 자리에 있는 사진은 비행기처럼 보이기도 한다
#
# 2. 생성 이미지 시각화 및 학습 그래프를 통해 GAN 학습이 바르게 진행되었음을 입증하였다.
#    gif를 통해 생성이미지 품질이 서서히 향상되는 것과, fake accuracy가 추세적으로 0.5를 향해 하향하고 있음을 확인하였다.
#    -> 아주 작은 기울기지만 오른쪽 아래로 기울고 있다
#
# 3. 추가적인 GAN 모델구조 혹은 학습과정 개선 아이디어를 제안하고 이를 적용하였다.
#    제출 아이디어를 제출 프로젝트에 반영하고, 그 결과가 아이디어 적용 이전보다 향상되었음을 시각적으로 입증하였다.
#    -> 흑백으로 할 때보다 컬러로 할때 정확도가 0.5에 가깝다
#    -> learning rate 를 10배로 올렸더니 전혀 알아볼 수 없는 이미지가 출력 되었다
#    너무 크게 바꾼 걸 수도 있고 작게 해야하는 걸 크게 만든 걸 수도 있다
